# %% [markdown]
# ## PART 1 (Ferry simulation)
# ![image-4.png](attachment:image-4.png)
#
# ## PART 2 (Aloha simulation)
#
# ### *Number of collisions and packages (9.6 kbps, 20 hosts)*
# ![image.png](attachment:image.png)
#
# ### *Number of collisions and packages (9.6 kbps, 10 hosts)*
# ![image-2.png](attachment:image-2.png)
#
# ### *Number of collisions and packages (19.2 kbps, 20 hosts)*
#
# ![image-3.png](attachment:image-3.png)
#
# *Rest of the histograms and vector plots are provided/saved in the project folder in "PureAloha1.anf"*
